# %%
from geopy import geocoders

# %%
import pandas as pd

# %%
g = geocoders.GoogleV3("AIzaSyCqTMWCA9KPXuNoBfNsd6e2UiMkOgavPDY")

# %%
#testing
g.geocode("Spain")
# Out:
# Location(Spain, (40.46366700000001, -3.74922, 0.0))

# %%
forest=pd.read_csv('forest.csv')

# %%
forest.head(6)
# Out:
#        Country       2015
# 0        Aruba   2.333333
# 1  Afghanistan   2.067825
# 2       Angola  46.407315
# 3      Albania  28.156934
# 4      Andorra  34.042553
# 5   Arab World   2.802680

# %%
countryList=forest['Country']

# %%
type(GDP)
# Out:
# pandas.core.frame.DataFrame

# %%
countryArray=GDP['country']

# %%
valueArray=GDP['2015Map']

# %%
valueArray
# Out:
# 0         1
# 1         2
# 2         9
# 3         2
# 4         1
# 5       192
# 6        28
# 7        45
# 8         2
# 9         1
# 10        1
# 11      101
# 12       30
# 13        5
# 14        1
# 15       35
# 16        2
# 17        2
# 18       16
# 19        5
# 20        3
# 21        2
# 22        2
# 23        5
# 24        1
# 25        1
# 26        3
# 27      136
# 28        1
# 29        2
#        ...
# 162       1
# 163       1
# 164       4
# 165       1
# 166       1
# 167       8
# 168       4
# 169      38
# 170       1
# 171       2
# 172       1
# 173      31
# 174       2
# 175       4
# 176       1
# 177       4
# 178      65
# 179       1
# 180       4
# 181       3
# 182       8
# 183       5
# 184    1353
# 185       6
# 186      15
# 187       1
# 188       1
# 189      25
# 190       3
# 191       2
# Name: 2015Map, Length: 192, dtype: int64

# %%
#get the lat/long coordinates of the countries
for country in countryList:
            placemark = g.geocode(country)
            print ( placemark[1][0],',' ,placemark[1][1],',')
# Out:
# 12.52111 , -69.968338 ,
# 33.93911 , 67.709953 ,
# -11.202692 , 17.873887 ,
# 41.153332 , 20.168331 ,
# 42.506285 , 1.521801 ,
# 33.82367 , -117.960126 ,
# 23.424076 , 53.847818 ,
# -38.416097 , -63.61667199999999 ,
# 40.069099 , 45.038189 ,
# -14.270972 , -170.132217 ,
# 17.060816 , -61.796428 ,
# -25.274398 , 133.775136 ,
# 47.516231 , 14.550072 ,
# 40.143105 , 47.576927 ,
# -3.373056 , 29.918886 ,
# 50.503887 , 4.469936 ,
# 9.30769 , 2.315834 ,
# 12.238333 , -1.561593 ,
# 23.684994 , 90.356331 ,
# 42.733883 , 25.48583 ,
# 26.0667 , 50.5577 ,
# 25.03428 , -77.39627999999999 ,
# 43.915886 , 17.679076 ,
# 53.709807 , 27.953389 ,
# 17.189877 , -88.49765 ,
# 32.3078 , -64.7505 ,
# -16.290154 , -63.58865299999999 ,
# -14.235004 , -51.92528 ,
# 13.193887 , -59.543198 ,
# 4.535277 , 114.727669 ,
# 27.514162 , 90.433601 ,
# -22.328474 , 24.684866 ,
# 6.611110999999999 , 20.939444 ,
# 56.130366 , -106.346771 ,
# 54.5259614 , 15.2551187 ,
# 46.818188 , 8.227511999999999 ,
# ...

# %%
forestFinal=pd.read_csv('forestFinal.csv',names=None,header=None)

# %%
forestFinal
# Out:
#              0           1     2  3
# 0    12.521110  -69.968338    40  2
# 1    33.939110   67.709953    36  2
# 2   -11.202692   17.873887   788  2
# 3    41.153332   20.168331   478  2
# 4    42.506285    1.521801   578  2
# 5    33.823670 -117.960126    48  2
# 6    23.424076   53.847818    67  2
# 7   -38.416097  -63.616672   169  2
# 8    40.069099   45.038189   198  2
# 9   -14.270972 -170.132217  1488  2
# 10   17.060816  -61.796428   378  2
# 11  -25.274398  133.775136   276  2
# 12   47.516231   14.550072   796  2
# 13   40.143105   47.576927   234  2
# 14   -3.373056   29.918886   183  2
# 15   50.503887    4.469936   383  2
# 16    9.307690    2.315834   649  2
# 17   12.238333   -1.561593   333  2
# 18   23.684994   90.356331   187  2
# 19   42.733883   25.485830   598  2
# 20   26.066700   50.557700    14  2
# 21   25.034280  -77.396280   873  2
# 22   43.915886   17.679076   724  2
# 23   53.709807   27.953389   723  2
# 24   17.189877  -88.497650  1017  2
# ...

# %%
for i in range(0,183):
    for j in range(0,4):
        print(forestFinal.iloc[i,j],',')
# Out:
# 12.52111 ,
# -69.968338 ,
# 40 ,
# 2 ,
# 33.93911 ,
# 67.709953 ,
# 36 ,
# 2 ,
# -11.202692 ,
# 17.873887 ,
# 788 ,
# 2 ,
# 41.153332 ,
# 20.168331 ,
# 478 ,
# 2 ,
# 42.506285 ,
# 1.521801 ,
# 578 ,
# 2 ,
# 33.82367 ,
# -117.960126 ,
# 48 ,
# 2 ,
# 23.424076 ,
# 53.847818 ,
# 67 ,
# 2 ,
# -38.416097 ,
# -63.616672 ,
# 169 ,
# 2 ,
# 40.069099 ,
# 45.038189 ,
# 198 ,
# 2 ,
# -14.270972 ,
# -170.132217 ,
# 1488 ,
# 2 ,
# 17.060816 ,
# -61.796428 ,
# 378 ,
# 2 ,
# -25.274398 ,
# 133.775136 ,
# 276 ,
# 2 ,
# 47.516231 ,
# 14.550072 ,
# 796 ,
# 2 ,
# 40.143105 ,
# 47.576927 ,
# 234 ,
# 2 ,
# -3.373056 ,
# 29.918886 ,
# 183 ,
# 2 ,
# 50.503887 ,
# 4.469936 ,
# 383 ,
# 2 ,
# 9.30769 ,
# 2.315834 ,
# 649 ,
# 2 ,
# 12.238333 ,
# -1.561593 ,
# 333 ,
# 2 ,
# 23.684994 ,
# 90.356331 ,
# 187 ,
# 2 ,
# 42.733883 ,
# 25.48583 ,
# 598 ,
# 2 ,
# 26.0667 ,
# 50.5577 ,
# 14 ,
# 2 ,
# 25.03428 ,
# -77.39628 ,
# 873 ,
# 2 ,
# 43.915886 ,
# 17.679076 ,
# 724 ,
# 2 ,
# 53.709807 ,
# 27.953389 ,
# 723 ,
# ...

# %%
data=pd.read_csv('visualnew.csv')

# %%
data.head(5)
# Out:
#          country        lat         lon  2013/14  2014/15  2015/16
# 0          China  35.861660  104.195397    87895    89540    91215
# 1       Malaysia   4.210484  101.975766    16635    17060    17405
# 2  United States  37.090240  -95.712891    16485    16865    17115
# 3          India  20.593684   78.962880    19750    18325    16745
# 4     Hong Kong   22.396428  114.109497    14725    16215    16745

# %%
from sklearn import preprocessing

# %%
output
# Out:
# array([[ 1.        ,  1.        ,  1.        ],
#        [ 0.13827922,  0.14016252,  0.13733053],
#        [ 0.13646532,  0.13784922,  0.13394109],
#        [ 0.17594776,  0.15516935,  0.12961664],
#        [ 0.1151823 ,  0.13013821,  0.12961664],
#        [ 0.15502751,  0.15036479,  0.12207807],
#        [ 0.04667755,  0.03974138,  0.03406966],
#        [ 0.01922728,  0.02431935,  0.02203132],
#        [ 0.0137856 ,  0.01180378,  0.00514259],
#        [ 0.01390652,  0.00984637,  0.0037985 ],
#        [ 0.1071407 ,  0.10000593,  0.09081346],
#        [ 0.07618357,  0.0796014 ,  0.08029453],
#        [ 0.05260294,  0.06263717,  0.07573633],
#        [ 0.07606264,  0.06714515,  0.05364656],
#        [ 0.06614668,  0.05795124,  0.04832866],
#        [ 0.01674829,  0.02129426,  0.02553763],
#        [ 0.01590181,  0.01595587,  0.0180575 ],
#        [ 0.01396699,  0.01198173,  0.00631136],
#        [ 0.        ,  0.        ,  0.        ]])
